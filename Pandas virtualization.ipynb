# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.randn(10,4),index=pd.date_range('1/1/2002',periods=10),columns=list('ABCD'))
print(df)
df.plot()
# Out:
#                    A         B         C         D
# 2002-01-01 -0.251060  1.227762 -0.469978  0.059312
# 2002-01-02  1.191266 -0.358766 -0.705023  2.442312
# 2002-01-03  0.590035 -0.375190 -0.071095 -0.680580
# 2002-01-04 -1.094074  1.522568 -1.973584  0.933490
# 2002-01-05 -0.765814 -0.119971  1.175314 -2.568813
# 2002-01-06  0.756280  0.150267 -0.873651  1.370218
# 2002-01-07  0.399574  1.459295 -0.375741  0.360431
# 2002-01-08 -1.649632  0.598458 -0.931638 -0.041941
# 2002-01-09  1.179512 -0.905880  0.725611 -0.106343
# 2002-01-10  0.429118 -0.224732  0.038379  0.366509

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.randn(10,2),index=pd.date_range('1/1/2002',periods=10),columns=list(['A','D']))
print(df)
df.plot()
# Out:
#                    A         D
# 2002-01-01  0.793417 -1.007507
# 2002-01-02  1.900836 -1.342579
# 2002-01-03 -0.172801 -0.397038
# 2002-01-04  0.225294  0.918607
# 2002-01-05 -0.175264  1.272064
# 2002-01-06 -0.334500  0.215911
# 2002-01-07 -0.413711  0.829445
# 2002-01-08 -1.048362 -0.657895
# 2002-01-09  1.161723 -0.707195
# 2002-01-10 -1.141128  0.392440

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.rand(10,4),columns=['A','B','C','D'])
print(df)
df.plot.bar()
# Out:
#           A         B         C         D
# 0  0.631507  0.967935  0.432796  0.953130
# 1  0.970215  0.495514  0.482796  0.270713
# 2  0.356478  0.774084  0.300429  0.157892
# 3  0.075870  0.244954  0.385375  0.360509
# 4  0.534324  0.649572  0.546225  0.699661
# 5  0.765748  0.272608  0.816735  0.515847
# 6  0.381674  0.931706  0.631943  0.912831
# 7  0.488363  0.410257  0.523660  0.215958
# 8  0.364756  0.495345  0.949721  0.754452
# 9  0.112440  0.024045  0.701133  0.323265

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.rand(10,4),columns=['A','B','C','D'])
print(df)
df.plot.bar(stacked=True)
# Out:
#           A         B         C         D
# 0  0.684319  0.548609  0.495938  0.117811
# 1  0.197518  0.111393  0.375944  0.545227
# 2  0.430019  0.121646  0.758615  0.689294
# 3  0.026115  0.563954  0.397396  0.128023
# 4  0.490013  0.722604  0.416297  0.192248
# 5  0.583498  0.925987  0.862122  0.546922
# 6  0.496967  0.090596  0.353038  0.588899
# 7  0.759451  0.659004  0.529178  0.960667
# 8  0.415882  0.253716  0.146279  0.524206
# 9  0.674888  0.172278  0.677949  0.962008

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.rand(10,3),columns=['A','B','C'])
print(df)
df.plot.bar(stacked=True)
# Out:
#           A         B         C
# 0  0.192088  0.117323  0.341034
# 1  0.911500  0.791788  0.420548
# 2  0.226519  0.511862  0.673905
# 3  0.741904  0.767864  0.856287
# 4  0.294671  0.221017  0.730508
# 5  0.752801  0.882752  0.383015
# 6  0.470423  0.419923  0.829162
# 7  0.988088  0.538590  0.017534
# 8  0.614097  0.077515  0.929021
# 9  0.967745  0.402730  0.471297

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.rand(10,4),columns=['A','B','C','D'])
print(df)
my_color=['aqua','green','yellow','red']
df.plot.barh(stacked=True,color=my_color)
# Out:
#           A         B         C         D
# 0  0.780520  0.491627  0.770792  0.304074
# 1  0.130588  0.031835  0.412313  0.925898
# 2  0.640371  0.380139  0.358801  0.522821
# 3  0.498359  0.350336  0.967430  0.114959
# 4  0.698922  0.005925  0.466756  0.881183
# 5  0.709962  0.816077  0.911522  0.673253
# 6  0.248039  0.059885  0.656503  0.540100
# 7  0.994734  0.828200  0.557971  0.092188
# 8  0.851960  0.994070  0.287430  0.652063
# 9  0.967879  0.042289  0.376513  0.484952

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame({'a':np.random.randn(1000)+1,'b':np.random.randn(1000),'c':np.random.randn(1000)-1},columns=['a','b','c'])
print(df)
df.plot.hist(bins=20)
# Out:
#             a         b         c
# 0    0.573742 -1.361592 -1.245579
# 1    1.916383  0.724886 -1.486383
# 2    0.152367  1.368603 -1.024067
# 3   -0.127451  0.287943 -1.703881
# 4    3.187750  0.478064 -1.754244
# 5    2.896209 -0.431514 -0.839418
# 6    0.614735  0.327192  0.113452
# 7    1.300857 -0.262363 -1.632776
# 8    1.945725 -0.289233 -1.044186
# 9   -0.462589  2.638565 -0.791231
# 10   1.945619  0.929449  0.100021
# 11   1.851444  1.635982  0.102621
# 12  -0.671124  0.005842 -0.517221
# 13   1.487775 -0.997408  0.071674
# 14   1.504366  0.819978 -1.557366
# 15  -0.675529  1.835720 -0.248416
# 16   0.253015  0.109386 -0.696901
# 17   1.558847  0.714941 -0.710469
# 18   1.942855  1.341042  0.157453
# 19   2.681884  0.703686 -0.116715
# 20   2.245513  0.612719 -1.096298
# 21   2.449585 -0.176214 -0.133886
# 22   1.763605  0.046265 -1.319520
# 23  -0.589056 -1.379206 -0.865887
# 24   0.421613  0.543617 -1.862842
# 25   0.647426  0.390414 -0.090945
# ...

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.rand(10,4),columns=['A','B','C','D'])
print(df)
df.plot.area()
# Out:
#           A         B         C         D
# 0  0.110719  0.856659  0.343011  0.522328
# 1  0.100846  0.975467  0.596903  0.943259
# 2  0.487160  0.862026  0.531160  0.769503
# 3  0.277476  0.068257  0.086579  0.936522
# 4  0.888513  0.348022  0.272508  0.489312
# 5  0.204617  0.638132  0.777324  0.091519
# 6  0.887812  0.866527  0.220649  0.975567
# 7  0.809930  0.629228  0.968081  0.848959
# 8  0.802156  0.979334  0.863550  0.937583
# 9  0.944022  0.025270  0.536131  0.780161

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.rand(10,4),columns=['A','B','C','D'])
print(df)
df.plot.box()
# Out:
#           A         B         C         D
# 0  0.057416  0.500652  0.985280  0.301308
# 1  0.299902  0.613028  0.391420  0.947254
# 2  0.063177  0.663452  0.196090  0.447264
# 3  0.916753  0.447277  0.712884  0.980890
# 4  0.968673  0.097424  0.257302  0.510860
# 5  0.613443  0.299112  0.394634  0.230375
# 6  0.586064  0.464697  0.825656  0.543039
# 7  0.212407  0.655591  0.099772  0.892825
# 8  0.413816  0.024780  0.271813  0.286225
# 9  0.525294  0.302793  0.216866  0.586097

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.rand(40,4),columns=['A','B','C','D'])
print(df)
df.plot.scatter(x='A',y='B',marker='*',color='red')
# Out:
#            A         B         C         D
# 0   0.055473  0.769260  0.351561  0.663048
# 1   0.858000  0.208099  0.618023  0.052255
# 2   0.863934  0.795441  0.492415  0.256953
# 3   0.393606  0.896688  0.838475  0.485008
# 4   0.901301  0.347817  0.908139  0.379113
# 5   0.452922  0.406788  0.271792  0.358435
# 6   0.678789  0.819892  0.911390  0.188913
# 7   0.107680  0.363775  0.215350  0.792430
# 8   0.843277  0.641659  0.910209  0.819853
# 9   0.010494  0.528747  0.720813  0.273474
# 10  0.732068  0.688385  0.767879  0.024665
# 11  0.386017  0.105232  0.458386  0.931831
# 12  0.469397  0.791121  0.683828  0.714058
# 13  0.187848  0.010940  0.916232  0.076756
# 14  0.050606  0.716760  0.082600  0.024403
# 15  0.947084  0.658430  0.632090  0.642786
# 16  0.672465  0.591715  0.563752  0.302992
# 17  0.248941  0.668797  0.524466  0.428883
# 18  0.774542  0.687812  0.349818  0.471060
# 19  0.184568  0.317489  0.440197  0.076604
# 20  0.739578  0.065067  0.722011  0.720932
# ...

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(3*np.random.rand(4),index=['A','B','C','D'],columns=['X'])
print(df)
df.plot.pie(subplots=True)
# Out:
#           X
# A  1.464986
# B  0.040667
# C  2.447740
# D  0.953391
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001E4155D5B00>],
#       dtype=object)
